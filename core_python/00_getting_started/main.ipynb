# %% [markdown]
# starting here

# %%
def main():
    print("name: ",__name__)
    print("package: ",__package__)
    print("File: ",__file__)

# %%
if __name__ == "__main__":
    print("hello world ......")
    main()
