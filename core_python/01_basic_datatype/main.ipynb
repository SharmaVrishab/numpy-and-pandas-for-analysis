# %%
"""
datatypes

"""

# boolean
b_true = True
v_false = False
x_none = None


#integers
i_1 = 123
i_2 = -456

#floats
f_1 = 3.14
f_2 = 0.0012345562132132132131

#strings
s_single = 'this is string'
s_double = "this is a string"
s_tripe = """you gussed it is a string !"""
s_wrap = """ and this string
             can span over
             multiple lines"""
#list
l_simple = [1, 2, 3, 4, 5]
l_mixed = [1, '2', b_true, i_2]
l_nested = [
    [1,2,3],
    ['1','2','3'],
    2,3,4
]


# tuple
t_basics = (1, 2, 3)
t_2 = 4,5,6,7


# dictionary
d_simple = {
                1:2,
                "3":3,
                True:False
            }


d_mixed = {
    "a" : 7,
    "x_none" : x_none,
    "s_double": s_double,
    "l_mixed" : l_mixed
}


d_nested = {
    "d_simple":d_simple,
    "d_mixed":d_mixed,
    "nested":{
        "l_simple":l_simple
    }
}

# %%
d_nested
